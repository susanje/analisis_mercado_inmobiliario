# %% [markdown]
# <a href="https://colab.research.google.com/github/susanje/analisis_mercado_inmobiliario/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Cargo las librerias a utilizar**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
from itertools import cycle, islice
import datetime as dt
from datetime import datetime, date
import numpy as np
from math import sqrt
from sklearn import linear_model 
from sklearn.preprocessing import PolynomialFeatures

# %%
from google.colab import files   
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e36520ce-5899-4bd5-8a25-54694d94115d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e36520ce-5899-4bd5-8a25-54694d94115d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Importo el archivo analizar**

# %%
import io 
  
data = pd.read_excel(io.BytesIO(uploaded['Real Estate Data Assessment.xlsx'])) 
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# **Veo la dimensionalidad del dataset**

# %%
data.shape
# Out:
# (22655, 10)

# %% [markdown]
# **Comienzo a analizar la información que contiene**

# %%
data.head(10) #observo el contenido de los datos para evaluar si todos son relevantes o debo dropear alguna columna
# Out:
#       inmueble    oferta      region          barrio    ciudad  area_metros  \
# 0  Apartamento  Arriendo  NorOriente    La Milagrosa  Medellín        130.0
# 1  Apartamento  Arriendo  SurOriente          Oviedo  Medellín        150.0
# 2  Apartamento  Arriendo  SurOriente       Castropol  Medellín        140.0
# 3  Apartamento  Arriendo  SurOriente      El Poblado  Medellín        111.0
# 4  Apartamento  Arriendo  SurOriente      El Poblado  Medellín        150.0
# 5  Apartamento  Arriendo   Occidente   Florida Nueva  Medellín        130.0
# 6  Apartamento  Arriendo   Occidente  Conquistadores  Medellín        120.0
# 7  Apartamento  Arriendo  SurOriente      Aguacatala  Medellín        105.0
# 8  Apartamento  Arriendo         NaN       los parra  Medellín        137.0
# 9  Apartamento  Arriendo         NaN         POBLADO  Medellín        107.0
#
#    baños     precio  habitaciones    estrato
# 0    2.0  1500000.0           3.0  Estrato 3
# ...

# %%
data.describe() #observo como estan distribuidos los datos
# Out:
#          area_metros         baños        precio  habitaciones
# count   22655.000000  22655.000000  2.265500e+04  22655.000000
# mean      160.791145      2.606489  6.357925e+08      2.895122
# std      2947.637190      1.117508  1.907184e+10      0.894714
# min         1.000000      0.000000  3.000000e+05      0.000000
# 25%        71.000000      2.000000  1.350000e+08      2.000000
# 50%       100.000000      2.000000  3.800000e+08      3.000000
# 75%       148.000000      3.000000  6.200000e+08      3.000000
# max    347347.000000     10.000000  2.750000e+12     20.000000

# %%
data.info() #observo los tipo de datos que contiene y si contiene nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22655 entries, 0 to 22654
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inmueble      22655 non-null  object
#  1   oferta        22655 non-null  object
#  2   region        16170 non-null  object
#  3   barrio        22652 non-null  object
#  4   ciudad        22655 non-null  object
#  5   area_metros   22655 non-null  float64
#  6   baños         22655 non-null  float64
#  7   precio        22655 non-null  float64
#  8   habitaciones  22655 non-null  float64
#  9   estrato       22655 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.7+ MB

# %%
data.isna().sum() #observo los datos vacios que trae cada columna
# Out:
# inmueble           0
# oferta             0
# region          6485
# barrio             3
# ciudad             0
# area_metros        0
# baños              0
# precio             0
# habitaciones       0
# estrato            0
# dtype: int64

# %% [markdown]
# Se puede observar que en la columna de región y barrio, existen valores faltantes, en region el total es de 6485 y en barrio el total es de 3

# %%
data.columns #veo el nombre de las columnas
# Out:
# Index(['inmueble', 'oferta', 'region', 'barrio', 'ciudad', 'area_metros',
#        'baños', 'precio', 'habitaciones', 'estrato'],
#       dtype='object')

# %% [markdown]
# **Tratamiento de los vacios**

# %%
data['region'].unique() #observo el contenido de los datos unicos en la columna a tratar
# Out:
# array(['NorOriente', 'SurOriente', 'Occidente', nan, 'SurOccidente',
#        'NorOccidente', 'Centro'], dtype=object)

# %%
import random

# %%
good_ones = ['NorOriente', 'SurOriente', 'Occidente','SurOccidente','NorOccidente', 'Centro'] #armo una lista con los datos correctos de la columna barrios 
region1 = [x for x in data['region']] #creo una funcion que recorra fila a fila los datos contenidos en la columna a tratar y los aloje en una lista
for r in range(0, len(region1)): #armo un for que itere por cada valor contenido en la lista que cree en el paso anterior, que comience en el valor 0 y se extienda por el tamaño total contenido en la lista
        if region1[r] == 'nan': 
            region1[r] = 'Unknown'
        elif region1[r] not in good_ones: #si el valor que contiene es distinto a alguno de los alojados en la lista good_ones
            region1[r] = random.choice(good_ones) #reemplazar de manera aleatoria por algun valor contenido en la lista good_ones, realizamos esto de este modo para que no se produzca un desbalance y los guarde en la lista creada

# %%
data['region'] = region1 #ahora le decimos que reemplace los datos contenidos en la columna a tratar por los contenidos en la lista creada

# %%
data.isna().sum() #volvemos a verificar los vacios y vemos que se han compleados los datos faltantes
# Out:
# inmueble        0
# oferta          0
# region          0
# barrio          3
# ciudad          0
# area_metros     0
# baños           0
# precio          0
# habitaciones    0
# estrato         0
# dtype: int64

# %% [markdown]
# La otra columna a tratar "barrio", tiene muchas entradas diversas por lo cual es mas complejo unificar el texto, no se puede utilizar el proceso usado anteriormente.

# %%
pd.set_option("display.max_rows", None)#pido que me muestre el total de datos contenido y no un resumen

# %%
data.barrio.value_counts() #miro los valores unicos y le pido que cuente la cantidad de ocurrencias que tiene en la columna
# Out:
# El Poblado                2495
# Laureles                  1845
# Calasanz                   837
# Robledo                    794
# Castropol                  758
#                           ...
# san julian                   1
# Poblado La Frontera          1
# Pobladp Provenza             1
# El Poblado La Inferior       1
# 20 DE JULIO                  1
# Name: barrio, Length: 1222, dtype: int64

# %%
data=data.sort_values(by='barrio', ascending=True) #ordeno de forma ascendente la columna a tratar

# %%
data_normalizada= data['barrio'] #separo la columna a tratar para luego de realizada la limpieza añadirla

# %%
data_normalizada=data_normalizada.fillna(method="bfill") #completo los 3 faltantes en base a lo que contiene la columna anterior

# %%
data_normalizada=data_normalizada.str.title() #funcion que transforma los datos en valores donde la primer letra es Mayúscula y el resto lo deja en minúscula

# %%
data_normalizada=data_normalizada.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8') #le quito las tildes

# %%
data_normalizada.drop_duplicates()#en caso de existir algun registro duplicado lo elimino comparando el valor de todas las columnas, sería idoneo hacerlo por id en caso de existir
# Out:
# 21768                                        12 De Octubre
# 4863     2 Poblado Envigado Sabaneta San Diego Las Palm...
# 22621                                          20 De Julio
# 7007     3 Laureles La America Estadio Conquistadores C...
# 2161     4 Rosales Belen La Mota Guayabal Itagui La Est...
# 22557                                           8 De Marzo
# 3240                                               Acevedo
# 9287                                            Aguacatala
# 247                                                Alameda
# 19710                                           Alejandria
# 7929                                    Alejandria Poblado
# 15008                                              Aliadas
# 17314                                             Almerias
# 19180                                   Alto De Las Flores
# 19406                                      Alto Las Palmas
# 12513                                              America
# ...

# %%
data_normalizada.unique()#observo los valores unicos
# Out:
# array(['12 De Octubre',
#        '2 Poblado Envigado Sabaneta San Diego Las Palmas Itagui La Estrella',
#        '20 De Julio',
#        '3 Laureles La America Estadio Conquistadores Castillas Pedregal Tricentenario Bello',
#        '4 Rosales Belen La Mota Guayabal Itagui La Estrella',
#        '8 De Marzo', 'Acevedo', 'Aguacatala', 'Alameda', 'Alejandria',
#        'Alejandria Poblado', 'Aliadas', 'Almerias', 'Alto De Las Flores',
#        'Alto Las Palmas', 'America', 'America Niza',
#        'Andalucia La Francia', 'Abadia', 'Aguacatala 2', 'Aldea',
#        'Alejandria Poblado Medellin', 'Alejandria El Poblado',
#        'Alfonso Lopez', 'Almeria', 'Altamira Robledo',
#        'Altas De Las Palmas', 'Alto De Palmas', 'Altos De Poblado',
#        'Altos Del Poblado', 'America Danubio', 'Andalucia', 'Aranjuez',
#        'Asomadera', 'Asomadera 1', 'Asomadera I', 'Astorga',
#        'Astorga Parque Del Poblado', 'Aures', 'Aurora De La Libertad',
# ...

# %%
data_normalizada.replace({'Sta': 'Santa'}, regex= True, inplace= True) #reemplazo las abreviaciones y Articulos
data_normalizada.replace({'Del': 'De'}, regex= True, inplace= True)
data_normalizada.replace({'I ': ''}, regex= True, inplace= True)
data_normalizada.replace({'Il': ''}, regex= True, inplace= True)
data_normalizada.replace({'L A': ''}, regex= True, inplace= True)
data_normalizada.replace({'No ':''}, regex= True, inplace= True)
data_normalizada.replace({'Nro ':''}, regex= True, inplace= True)
data_normalizada.replace({'Comuna': ''}, regex= True, inplace= True)
data_normalizada.replace({'Ed ':'Edificio '}, regex= True, inplace= True)
data_normalizada.replace({'Zuiga': 'Zuniga'}, regex= True, inplace= True)
data_normalizada.replace({'  ':' '}, regex= True, inplace= True)
data_normalizada.replace({'Av ': 'Avenida '}, regex= True, inplace= True)
data_normalizada.replace({'B ': 'Barrio '}, regex= True, inplace= True)
data_normalizada.replace({'Barrio': ''}, regex= True, inplace= True)
data_normalizada.replace({'La ': ''}, regex= True, inplace= True)
data_normalizada.replace({'El ': ''}, regex= True, inplace= True)
data_normalizada.replace({'N 1': ''}, regex= True, inplace= True)
data_normalizada.replace({'Occidente ': ''}, regex= True, inplace= True)
data_normalizada.replace({'Los':''}, regex= True, inplace= True)
data_normalizada.replace({'Las':''}, regex= True, inplace= True)
data_normalizada.replace({'Loma De ':''}, regex= True, inplace= True)
data_normalizada.replace({'Loma ':''}, regex= True, inplace= True)
data_normalizada.replace({'Lomas ':''}, regex= True, inplace= True)
data_normalizada.replace({'Sur Poblado':''}, regex= True, inplace= True)

# %%
import re
data_normalizada.replace({'  ':''}, regex= True, inplace= True) 
data_normalizada.replace({'   ':''}, regex= True, inplace= True) #reemplazo los valores vacios que puedan haber surgido del paso anterior

# %%
data_normalizada=data_normalizada.str.strip()#elimino espacios en blanco al principio y al final

# %%
data_normalizada=data_normalizada.fillna(method="bfill")#relleno los espacios en blanco en base al registro anterior

# %%
data_normalizada.loc[data_normalizada.isin(['Poblado Alejandria','Poblado Astorga', 'Poblado Campestre', 'Poblado Castropol','Poblado Ciudad De Rio', 'Poblado Clinica Medellin','Poblado Tesoro', 'Poblado Calera', 'Poblado nferior','Poblado Linde', 'Poblado Tomatera', 'Poblado Lalinde','Poblado Palmas','Poblado De Encierro', 'Poblado Balsos','Poblado De San Julian', 'Poblado Loma De Campestre','Poblado De ndio', 'Poblado De Tesoro','Poblado ndio', 'Poblado Balsos', 'Poblado Yarumos','Poblado Milla De Oro', 'Poblado Oviedo', 'Poblado Patio Bonito','Poblado San Fernando', 'Poblado San Lucas','Poblado Santa Maria De Angeles', 'Poblado Sector Bagatela','Poblado Sector Aguacatala', 'Poblado Sector Vizcaya','Poblado Sur', 'Poblado Suroriente','Poblado Alto', 'Altos Del Poblado','Avenida De Poblado','Poblado Altos De Poblado', 'Poblado Altos Depoblado','Poblado Balsos', 'Poblado Balsos 2', 'Poblado Balsos Con nferir','Santas Poblado','Poblado Campestre Drive nn', 'Poblado Cola De Zorro','Poblado Castillo', 'Poblado Diamante', 'Poblado Guamal','Poblado Entre Balsos Y Gonzalez', 'Poblado Frontera','Poblado nterlomas', 'Poblado Aguacatala', 'Poblado Concha','Poblado Florida', 'Poblado Toja', 'Poblado 2', 'Seleccione','Poblado 1', 'Poblado Santas','Poblado De Gonzalez', 'Poblado De Parra', 'Poblado Lalinde', 'Poblado Balsos', 'Poblado I','Poblado Inferior', 'PobladoLomas', 'PobladoPalmas','Poblado Encierro', 'PobladoBalsos', 'Poblado Indio','PobladoYarumos', 'Poblado Santa Maria DeAngeles','Poblado Balsos Con Inferir', 'Poblado Campestre Drive Inn','Poblado EntreBalsos YGonzalez', 'Poblado Interlomas', 'Poblado2','Poblado1', 'PobladoSantas', 'PobladoGonzalez', 'PobladoParra','PobladoBalsos 1', 'PobladoBalsos 2', 'Poblado ViaPalmas','Poblado Gonzalez', 'Poblado Marianito','Poblado Balsos 1', 'Poblado Balsos 2', 'Poblado Parra', 'Poblado Lv', 'Poblado Manila', 'Poblado Oa','Poblado Parte Baja', 'Poblado Provenza', 'Poblado San Julian', 'Poblado Sector Manila', 'Poblado Sector Oviedo','Poblado Transversal Superior', 'Poblado Via Palmas','Poblado Vizcaya', 'Pobladp Provenza'])] = 'Poblado'
data_normalizada.loc[data_normalizada.isin(['Alejandria Poblado','Alejandria Poblado Medellin'])] = 'Alejandria'
data_normalizada.loc[data_normalizada.isin(['Altas De Palmas','Alto De Palmas', 'Alto Palmas', 'nferior Con Palmas','Altos De Palmas','AltoPalmas'])] = 'Palmas'
data_normalizada.loc[data_normalizada.isin(['Almerias'])] = 'Almeria'
data_normalizada.loc[data_normalizada.isin(['Aguacatala 2'])] = 'Aguacatala'
data_normalizada.loc[data_normalizada.isin(['Altos De Poblado'])] = 'Altos Del Poblado'
data_normalizada.loc[data_normalizada.isin(['America Danubio', 'America Niza','12 America','Americas','A Merica'])] = 'America'       
data_normalizada.loc[data_normalizada.isin(['Balsos Parte Alta'])] = 'Balsos'
data_normalizada.loc[data_normalizada.isin(['Barichara San Antonio De Prado'])] = 'Barichara'
data_normalizada.loc[data_normalizada.isin(['Andalucia Francia'])] = 'Andalucia'
data_normalizada.loc[data_normalizada.isin(['Aguacatala 2'])] = 'Aguacatala'
data_normalizada.loc[data_normalizada.isin(['Asomadera 1','Asomadera I'])] = 'Asomadera'
data_normalizada.loc[data_normalizada.isin(['Astorga Parque De Poblado'])] = 'Astorga'
data_normalizada.loc[data_normalizada.isin(['Barrio Perez Bello Ant', 'Perez Bello Ant'])] = 'Perez Bello'
data_normalizada.loc[data_normalizada.isin(['Santafe'])] = 'Santa Fe'
data_normalizada.loc[data_normalizada.isin(['Belen Alameda', 'Belen Aliadas', 'Belen Alpes', 'Belen Altavista', 'Belen Malibu 2','Belen Buena Vista', 'Belen Fatima', 'Belen Fatima Malibu','Belen Granada', 'Belen Guayabal La Mota', 'Belen Castellana','Belen Gloria', 'Belen nmaculada', 'Belen Mota','Belen Nubia', 'Belen Palma', 'Belen Acacias','Belen Margaritas', 'Belen Mercedes', 'Belen Playas','Belen Violetas', 'Belen De Bernal','Belen Bernal', 'Belen Alpes', 'Belen Alpinos', 'Parque De Belen','Belen Inmaculada','BelenAcacias', 'BelenMargaritas', 'BelenMercedes', 'BelenPlayas','BelenVioletas', 'BelenBernal', 'BelenAlpes', 'BelenAlpinos','BelenMolinos', 'Belen Nogal', 'Belen Nogales','Belen Molinos', 'Belen Malibu', 'Belen Malibu ','Belen Mira Valle', 'Belen Miravalle', 'Belen gal', 'Belen gales','Belen Parque', 'Belen Porvenir', 'Belen Rincon', 'Belen Rodeo','Belen Rodeo Alto', 'Belen Rosales', 'Belen San Bernardo','Belen Veleros','Belen Guayabal Mota', 'Belencito Betania','Belen Vicuna', 'Belencito', 'Belencito Betania ','Beln San Bernardo', 'Belen Palma', 'Belen De Bernal'])] = 'Belen'
data_normalizada.loc[data_normalizada.isin(['Bello Guasimalito ', 'Bello Horizonte', 'Bello Navarra','Bello Niquia'])] = 'Bello'
data_normalizada.loc[data_normalizada.isin(['Balsos 1','Balsos N 2', 'Balsos Nro 1', 'Balsos Nro 2', 'Balsos Poblado','Balsos Superior', 'Balsos i', 'Balsos l','Balsos Ii', 'Balsos 2'])] = 'Balsos'
data_normalizada.loc[data_normalizada.isin(['Bombona Nro 1', 'Bombona 1'])] = 'Bombona'
data_normalizada.loc[data_normalizada.isin(['Boston Centro'])] = 'Boston'
data_normalizada.loc[data_normalizada.isin(['Boyaca Brisas','BoyacaBrisas'])] = 'Boyaca'
data_normalizada.loc[data_normalizada.isin(['Buenos Aires 8 De Marzo', 'Buenos Aires Medellin','Buenos Aires Suroriente'])] = 'Buenos Aires'
data_normalizada.loc[data_normalizada.isin(['Calasania','Calasanz Floresta','Calasanz Noroccidente','Calasanz Mall Santa Ana', 'Calasanz Medellin','Calasanz roccidente', 'Calasanz Occidente', 'Calasanz Parte Alta','Calasanz Parte Baja', 'Calazania', 'Calazans', 'Calazanz'])] = 'Calasanz'
data_normalizada.loc[data_normalizada.isin(['Caldas Antioquia'])] = 'Caldas'
data_normalizada.loc[data_normalizada.isin(['Campo Valdes'])] = 'Campo Valdez'
data_normalizada.loc[data_normalizada.isin(['Castellana Occidente'])] = 'Castellana'
data_normalizada.loc[data_normalizada.isin(['Castropol Lv', 'Castropol Medellin','Castropol Parte Baja', 'Castropol Poblado'])] = 'Castropol'
data_normalizada.loc[data_normalizada.isin(['Centro Bombona', 'Centro Centro', 'Centro De Ciudad','Centro De Medellin', 'Centro Candelaria', 'Centro Oriental','Centro Prado', 'Centro Prado Centro', 'Centro Salvador','Centroccidental Conquistadores','Zona Centro'])] = 'Centro'
data_normalizada.loc[data_normalizada.isin(['Ciudad De Rio Poblado'])] = 'Ciudad De Rio'
data_normalizada.loc[data_normalizada.isin(['Conquistadores Medellin','Conquistadores Occidente','3 Laureles America Estadio Conquistadores Castillas Pedregal Tricentenario Bello'])] = 'Conquistadores'
data_normalizada.loc[data_normalizada.isin(['Copacabana Antioquia'])] = 'Copacabana'
data_normalizada.loc[data_normalizada.isin(['Cordoba Noroccidente'])] = 'Cordoba'
data_normalizada.loc[data_normalizada.isin(['Cristorey'])] = 'Cristo Rey'
data_normalizada.loc[data_normalizada.isin(['Cuidad De Rio'])] = 'Ciudad De Rio'
data_normalizada.loc[data_normalizada.isin(['Robledo Aurora', 'Robledo Bello Horizonte', 'Robledo Diamante','Robledo Fuente Clara', 'Robledo Kenedy', 'Robledo Aurora','Robledo Campina', 'Robledo Pola', 'Robledo Margaritas','Robledo Mirador De Pilarica', 'Robledo Pajarito','Robledo Pajarito Medellin', 'Robledo Palenque','Robledo Pilarica', 'RobledoMargaritas','Robledo Santa Maria', 'Robledo Villa Sofa','Robledo Villa Sofia'])] = 'Robledo'
data_normalizada.loc[data_normalizada.isin(['10 Candelaria'])] = 'Candelaria'
data_normalizada.loc[data_normalizada.isin(['13 San Javier','San Javier 1', 'San Javier Departamento', 'San Javier Medellin',])] = 'San Javier'
data_normalizada.loc[data_normalizada.isin(['5 Castilla'])] = 'Castilla'
data_normalizada.loc[data_normalizada.isin(['9 Buenos Aires'])] = 'Buenos Aires'
data_normalizada.loc[data_normalizada.isin(['Doce De Octubre'])] = '12 De Octubre'
data_normalizada.loc[data_normalizada.isin(['Caampestre','Campestre Poblado','Campetre Toja','Caampestre','Campestre Poblado','Campetre Toja'])] = 'Campestre'
data_normalizada.loc[data_normalizada.isin(['Castillo Poblado'])] = 'Castillo'
data_normalizada.loc[data_normalizada.isin(['Diamante 2', 'Diamante i','Diamante Nro 2','Diamante Ii'])] = 'Diamante'
data_normalizada.loc[data_normalizada.isin(['NogalAlmendros'])] = 'Nogal'
data_normalizada.loc[data_normalizada.isin(['Tesoro Poblado','Tesoro Parte Alta Poblado','Tesoro Poblado Medellin'])] = 'Tesoro'
data_normalizada.loc[data_normalizada.isin(['Envigado ', 'Envigado Ayura','EnvigadoVegas Cerca A Jumbo', 'Envigado Chocho', 'Envigado Esmeraldal','Envigado Vegas Cerca A Jumbo', 'Envigado De Chocho','Envigado Muga','Envigado Zuniga'])] = 'Envigado'
data_normalizada.loc[data_normalizada.isin(['Velodromo Occidente','Estadio Velodromo', 'Estadio','Velodromo Olivos','VelodromoOlivos'])] = 'Velodromo'
data_normalizada.loc[data_normalizada.isin(['Florida Nueva', 'Florida Nueva Occidente'])] = 'Florida'
data_normalizada.loc[data_normalizada.isin(['Guayabal 15'])] = 'Guayabal'
data_normalizada.loc[data_normalizada.isin([ 'Itagi', 'Itagui', 'tagui ', 'Itagui Santamaria ','Urbanizacion Plaza Mayorca Itagi','Itagui Santamaria','Suramerica Itagui','Itagui Suramerica','4 Rosales Belen Mota Guayabal Itagui Estrella','tagui Santamaria','tagui Suramerica','2 Poblado Envigado Sabaneta San DiegoPalmas Itagui Estrella'])] = 'Itagui'
data_normalizada.loc[data_normalizada.isin(['Esmeraldal'])] = 'Esmeraldas'
data_normalizada.loc[data_normalizada.isin(['Laureles Almeria','Laureles Avenida Nutibara', 'Laureles Bolivariana','Laureles Camelia', 'Laureles Castellana','Laureles Conquistadores', 'Laureles Estadio','Laureles Mall Laureles', 'Laureles Medellin', 'Laureles Nutibara','Laureles Parque', 'Laureles Santa Gema','Laureles Santa Teresita', 'Laureles Sector Pepe Ganga','Laureles Sector Santa Teresita', 'Laureles Segundo Parque','Laureles Simon Bolivar', 'Laureles gal', 'Laureles gal Medellin','LaurelesAcacias', 'LaurelesAcasias','Laureles Nogal','Laureles Nogal Medellin', 'Laureles Occidente'])] = 'Laureles'
data_normalizada.loc[data_normalizada.isin(['Prado Centro', 'Prado Centro Medellin','Pradera','Pradito'])] = 'Prado'
data_normalizada.loc[data_normalizada.isin(['Floresta Parque','Floresta Pradera', 'Floresta Santa Lucia','Floresta Occidente'])] = 'Floresta'
data_normalizada.loc[data_normalizada.isin(['Frontera Con Inferior', 'Frontera Poblado'])] = 'Frontera'
data_normalizada.loc[data_normalizada.isin(['Playas', 'Playa En Centro De Medellin'])] = 'Playa'
data_normalizada.loc[data_normalizada.isin(['Sur Oriente Oviedo', 'Sur Oriente Park 10','Sur Oriente Poblado', 'Sur Oriente San Diego', 'Conjunto Residencial Uno Sur','Sur Oriente Tesoro', 'Sur Oriente','Sur San Diego', 'Sur Indio','Suramerica tagui', 'Suramericana','Suramericana Estadio Medellin', 'Suramericano Estadio','Suroccidental Santa Fe', 'Suroccidente', 'Suroriente'])] = 'Sur'
data_normalizada.loc[data_normalizada.isin(['Flor'])] = 'Florencia'
data_normalizada.loc[data_normalizada.isin(['San Diego Poblado','Sandiego'])] = 'San Diego'
data_normalizada.loc[data_normalizada.isin(['San Joaquin Lv'])] = 'San Joaquin'
data_normalizada.loc[data_normalizada.isin(['San Julian Poblado'])] = 'San Julian'
data_normalizada.loc[data_normalizada.isin(['AvenidaPalmas'])] = 'Avenida Palmas'
data_normalizada.loc[data_normalizada.isin(['Aurora De Libertad'])] = 'Aurora'
data_normalizada.loc[data_normalizada.isin(['Altos DePalmas'])] = 'Palmas'
data_normalizada.loc[data_normalizada.isin(['Alto DeFlores'])] = 'Alto De Flores'
data_normalizada.loc[data_normalizada.isin(['Palmas', 'Palmas Country Club Poblado','Palmas Poblado', 'Altas DePalmas','Avenida Palmas','Inferior ConPalmas','Poblado ViaPalmas','Palmas Intercontinental Country Club Poblado','Palmas ntercontinental Country Club Poblado','Palmitas','Country','Altos De Las Palmas'])] = 'Palma'
data_normalizada.loc[data_normalizada.isin(['Oviedo Poblado'])] = 'Oviedo'       
data_normalizada.loc[data_normalizada.isin(['Pilarica', 'Pilarica i', 'Pilarica roccidente','Pilarica Ii', 'Pilarica Noroccidente'])] = 'Pilanca'
data_normalizada.loc[data_normalizada.isin(['Rodeo Alto','Rodeo Alto Hondonada'])] = 'Rodeo'
data_normalizada.loc[data_normalizada.isin(['Nororiente','oriente', 'Nororiente Campo Valdes','Nororiente Manrique','Oriente Milagrosa'])] = 'Oriente'
data_normalizada.loc[data_normalizada.isin(['a Vegas','Vegas De Poblado'])] = 'Vegas'
data_normalizada.loc[data_normalizada.isin(['Inidio','Indio Poblado', 'Indio Palmas', 'Indio Suroriente'])] = 'Indio'
data_normalizada.loc[data_normalizada.isin(['Bernales', 'DeBernal'])] = 'Bernal'
data_normalizada.loc[data_normalizada.isin(['Noroccidente', 'Sur Occidente'])] = 'Occidente'
data_normalizada.loc[data_normalizada.isin(['Sabaneta Doctora','Sabaneta Medellin Antioquia', 'Sabaneta San Jose','SabanetaLomitas'])] = 'Sabaneta'
data_normalizada.loc[data_normalizada.isin(['Medellin Conquistadores','Medellin Frontera', 'Medellin Laureles Santa Gema','Medellin Pedregal', 'MedellinPalmas', 'Medelln ndio'])] = 'Medellin'
data_normalizada.loc[data_normalizada.isin(['Manrique Central','Manrique Central Nro 1', 'Manrique Oriental','ManriqueEsmeraldas', 'Manrique Central I', 'Manrique Central 1'])] = 'Manrique'
data_normalizada.loc[data_normalizada.isin(['Naranjal'])] = 'Naranjos'
data_normalizada.loc[data_normalizada.isin(['Linde Poblado','Linde Poblado','Lalinde'])] = 'Linde'
data_normalizada.loc[data_normalizada.isin(['De Escobero'])] = 'Escobero'
data_normalizada.loc[data_normalizada.isin(['Lorena'])] = 'Lorena Laureles'
data_normalizada.loc[data_normalizada.isin(['Gonzales','Gonzales Poblado', 'Gonzalez Poblado'])] = 'Gonzalez'
data_normalizada.loc[data_normalizada.isin(['Villa Hermosa Angeles','Villahermos','Villahermosa', 'Villa HermosaAngeles'])] = 'Villa Hermosa'
data_normalizada.loc[data_normalizada.isin(['Villanueva'])] = 'Villa Nueva'
data_normalizada.loc[data_normalizada.isin(['Visitacin'])] = 'Visitacion'
data_normalizada.loc[data_normalizada.isin(['Viscaya'])] = 'Vizcaya'
data_normalizada.loc[data_normalizada.isin(['Transv Superior', 'Transv nferior', 'Transversal Superior', 'Transversal Superior Poblado', 'Transversal nferior','Transversal ntermedia','Transv Inferior','Transversal', 'Transversal Inferior', 'Transversal Intermedia'])] = 'Transversal'
data_normalizada.loc[data_normalizada.isin(['Niquia Quitasol'])] = 'Niquia'
data_normalizada.loc[data_normalizada.isin(['Parras'])] = 'Parra'
data_normalizada.loc[data_normalizada.isin(['San Michel'])] = 'San Miguel'
data_normalizada.loc[data_normalizada.isin(['San German Robledo', 'San German Tierra Firme'])] = 'San German'
data_normalizada.loc[data_normalizada.isin(['San Lucas Medellin', 'San Lucas Poblado'])] = 'San Lucas'
data_normalizada.loc[data_normalizada.isin(['Santa Fe Guayabal'])] = 'Santa Fe'
data_normalizada.loc[data_normalizada.isin(['Santa M De Angeles', 'Santa Mara De Ngeles','Santa M DeAngeles', 'Santa Mara DeNgeles','Santa Maria De Angeles', 'Santa Maria DeAngeles','Santa Maria DeAngeles Poblado', 'Santa Monica','Santa Rita San Antonio De Prado', 'Santa Margarita', 'Santa Maria', 'Santa Maria De Angeles Poblado','Santa Maria Itagui','Santamaria DeAngeles Poblado','Santas','Santas Poblado','Poblado Santa Maria DeAngeles','Angeles'])] = 'Santa Maria De Angeles'
data_normalizada.loc[data_normalizada.isin(['Santa Monica 1','Santa Monica 2', 'Santa Monica Medellin', 'Santa Monica i','Santa Monica I', 'Santa Monica Ii'])] = 'Santa Monica'
data_normalizada.loc[data_normalizada.isin(['1', '2', 'I', 'Ii', '', 'N1'])] = 'Poblado'
data_normalizada.loc[data_normalizada.isin(['Sucre Boston'])] = 'Sucre'
data_normalizada.loc[data_normalizada.isin(['San Antonios De Prado'])] = 'San Antonio De Prado'
data_normalizada.loc[data_normalizada.isin(['Provenza'])] = 'Provincia'
data_normalizada.loc[data_normalizada.isin(['Municipio Rio Negro', 'Rionegro','Colegios Rionegro'])] = 'Rio Negro'
data_normalizada.loc[data_normalizada.isin(['Medelln Indio'])] = 'Medellin'
data_normalizada.loc[data_normalizada.isin(['Colores Noroccidente', 'Colores Occidente'])] = 'Colores'
data_normalizada.loc[data_normalizada.isin([ 'Parte Alta De Patio Bonito', 'Patio Bonito Poblado'])] = 'Patio Bonito'
data_normalizada.loc[data_normalizada.isin([ 'Inter'])] = 'Intercontinental'
data_normalizada.loc[data_normalizada.isin([ 'Nuevos Conquistadores'])] = 'Conquistadores'
data_normalizada.loc[data_normalizada.isin(['Simon Bolivar Medellin'])] = 'Simon Bolivar'

# %%
data['barrio']= data_normalizada #creo una columna con la columna que guarde previamente

# %% [markdown]
#  **Detección de Outliers**

# %%
import seaborn as sns

# %%
column ={'precio':1} 
plt.figure(figsize=(25,30))
for variable, i in column.items(): 
  plt.subplot(5,4,i)
  plt.boxplot(data[variable])
  plt.title(variable)

plt.show()

# %%
plt.figure(figsize=(25,30))
for variable, i in column.items(): 
  plt.subplot(5,4,i)
  sns.distplot(data[variable])
  plt.title(variable)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# En ambos gráficos se observa la presencia de outliers

# %% [markdown]
# *Tratamiento de Outliers*

# %%
Q3 = data['precio'].quantile(0.75) #busco los cuartiles, primero arranco por el cuartil superior
Q1 = data['precio'].quantile(0.25) #continuo por el cuartil inferior
IQR = Q3-Q1 #creo una varible que contenga la resta de ambos para conocer el valor medio
upper = Q3+(1.5*IQR)#establezco maximos
lower = Q1-(1.5*IQR)#establezco minimos aceptados
(upper,lower)
# Out:
# (1347500000.0, -592500000.0)

# %%
data = data[(data['precio']>lower) & (data['precio']<upper)] #filtro los precios que solo esten dentro del rango establecido

# %%
sns.set(style="darkgrid")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(data=data,x='precio', ax=ax_box)
sns.histplot(data=data, x="precio", ax=ax_hist,kde=True)
ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# Se observa que existen varios valores cercanos a 0, por lo cual vamos a analizarlos

# %%
from scipy import stats
from scipy.stats import boxcox,yeojohnson

# %%
data['precio'] = (yeojohnson(data['precio'])[0]) #uso la transformacion yeo-johnsos de scipy para obtener un grafico distribuido de manera mas cercana lo normal
sns.set(style="darkgrid")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(data=data,x='precio', ax=ax_box)
sns.histplot(data=data, x="precio", ax=ax_hist,kde=True)
ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# Se puede observar claramente 2 tendencias de distribucion, se infiere que una refiere a los precios refieren a las operaciones de alquiler en un principio y las de ventas luego. Para ello vamos a dividir el set de datos en alquileres y ventas y volver a graficar

# %%
data['oferta'].unique()
# Out:
# array(['Venta', 'Arriendo'], dtype=object)

# %%
data_arriendo=data[data['oferta'].isin(['Arriendo'])]#filtro el dataset con solo estos datos  y armo 2 dataframe nuevos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c77e274228fa> in <module>
# ----> 1 data_arriendo=data[data['oferta'].isin(['Arriendo'])]#filtro el dataset con solo estos datos  y armo 2 dataframe nuevos
#
# NameError: name 'data' is not defined

# %%
data_arriendo['precio'] = (yeojohnson(data_arriendo['precio'])[0]) #uso la transformacion yeo-johnsos de scipy para obtener un grafico distribuido de manera mas cercana lo normal
sns.set(style="darkgrid")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(data=data_arriendo,x='precio', ax=ax_box)
sns.histplot(data=data_arriendo, x="precio", ax=ax_hist,kde=True)
ax_box.set(xlabel='')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_venta=data[data['oferta'].isin(['Venta'])]

# %%
data_venta['precio'] = (yeojohnson(data_venta['precio'])[0]) #uso la transformacion yeo-johnsos de scipy para obtener un grafico distribuido de manera mas cercana lo normal
sns.set(style="darkgrid")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(data=data_venta,x='precio', ax=ax_box)
sns.histplot(data=data_venta, x="precio", ax=ax_hist,kde=True)
ax_box.set(xlabel='')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Ahora sí se puede observar de manera correcta la distribucion de la variable precio

# %% [markdown]
# **Guardo la data limpia en un csv**

# %%
data.to_csv('susanje.csv',index=False)

# %%
from google.colab import files
files.download("susanje.csv")

# %% [markdown]
# USO DE SQL

# %%
# importo sqlalchemy and creo un servidor sqlite
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# Export el dataframe como una tabla llamada 'inmobiliario' para el servidor sqlite
data.to_sql("inmobiliario", con=engine)

# %%
result = engine.execute("SELECT * FROM inmobiliario")#guardo dentro de result la consulta que quiero realizar

# %%
dataframe = pd.DataFrame(result.fetchall())#convierto en dataframe la consulta realizada
dataframe.columns = result.keys()
dataframe.head()
# Out:
#    index     inmueble    oferta      region        barrio    ciudad  \
# 0      0  Apartamento  Arriendo  NorOriente  La Milagrosa  Medellín
# 1      1  Apartamento  Arriendo  SurOriente        Oviedo  Medellín
# 2      2  Apartamento  Arriendo  SurOriente     Castropol  Medellín
# 3      3  Apartamento  Arriendo  SurOriente    El Poblado  Medellín
# 4      4  Apartamento  Arriendo  SurOriente    El Poblado  Medellín
#
#    area_metros  baños     precio  habitaciones    estrato
# 0        130.0    2.0  1500000.0           3.0  Estrato 3
# 1        150.0    3.0  3400000.0           3.0  Estrato 6
# 2        140.0    3.0  5500000.0           2.0  Estrato 6
# 3        111.0    3.0  2990000.0           3.0  Estrato 6
# 4        150.0    3.0  3300000.0           3.0  Estrato 6

# %%
query = engine.execute("SELECT inmueble, region, barrio FROM inmobiliario WHERE precio > 1500000 AND estrato NOT LIKE 'Estrato 3'") #realizo otra consulta pero esta vez le pongo condiciones

# %%
df = pd.DataFrame(query.fetchall())#guardo en un dataframe la consulta
df.columns = query.keys()
df.head()
# Out:
#       inmueble      region         barrio
# 0  Apartamento  SurOriente         Oviedo
# 1  Apartamento  SurOriente      Castropol
# 2  Apartamento  SurOriente     El Poblado
# 3  Apartamento  SurOriente     El Poblado
# 4  Apartamento   Occidente  Florida Nueva

# %%
query1= engine.execute("SELECT DISTINCT barrio,region,precio FROM inmobiliario ORDER BY precio ASC") #veo los barrios y la region con inmuebles de mayor precio

# %%
df1 = pd.DataFrame(query1.fetchall())#guardo en un dataframe la consulta
df1.columns = query1.keys()
df1.head()
# Out:
#         barrio        region    precio
# 0  El Salvador        Centro  300000.0
# 1      Robledo  NorOccidente  320000.0
# 2  El Salvador        Centro  370000.0
# 3   NorOriente    NorOriente  420000.0
# 4      Robledo  NorOccidente  450000.0

# %%
query2= engine.execute("UPDATE inmobiliario SET barrio = 'Nueva Florida' WHERE barrio = 'Florida Nueva'")#cambio Florida nueva por Nueva Florida

# %%
query = engine.execute("SELECT inmueble, region, barrio FROM inmobiliario WHERE precio > 1500000 AND estrato NOT LIKE 'Estrato 3'") #hago la misma consulta para ver si guardo el cambio anterior

# %%
df = pd.DataFrame(query.fetchall())
df.columns = query.keys()
df.head()
# Out:
#       inmueble      region         barrio
# 0  Apartamento  SurOriente         Oviedo
# 1  Apartamento  SurOriente      Castropol
# 2  Apartamento  SurOriente     El Poblado
# 3  Apartamento  SurOriente     El Poblado
# 4  Apartamento   Occidente  Nueva Florida
